# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# $PEAK: possibly delisted; no timezone found
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 1.762035608291626 seconds.
# Csv file size 14.154708999999999 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
# import dask.dataframe as dd
import dask
dask.config.set({'dataframe.query-planning': True})
import dask.dataframe as dd
# Out:
# c:\Users\xiaoy\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 1.6445732116699219 seconds.
# Parquet file size 5.561300999999999 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\xiaoy\AppData\Local\Temp\ipykernel_26600\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# <dask_expr.expr.DataFrame: expr=Assign(frame=Assign(frame=Assign(frame=Assign(frame=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquet(d5cd2d2), _other=ticker, options={}), observed=False, group_keys=False, func=<function <lambda> at 0x000001BED1247CA0>, meta=_NoDefault.no_default, args=(), kwargs={})))))))>

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.875483   35.005930   34.640675
# A      2013-12-03 00:00:00-05:00   34.516736   34.679799   34.281928
# A      2013-12-04 00:00:00-05:00   34.464567   35.110291   34.386300
# A      2013-12-05 00:00:00-05:00   34.797202   35.090711   34.647187
# A      2013-12-06 00:00:00-05:00   35.064640   35.827762   35.064640
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  127.913548  128.386458  126.642582
# YUM    2024-01-26 00:00:00-05:00  128.002206  128.760844  126.770657
# YUM    2024-01-29 00:00:00-05:00  127.194317  128.622910  126.396261
# YUM    2024-01-30 00:00:00-05:00  128.435723  129.283029  127.667238
# YUM    2024-01-31 00:00:00-05:00  129.509619  130.031795  127.351944
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.705898  2039962        0.0           0.0  2013          NaN
# A        34.523258  3462706        0.0           0.0  2013    34.705898
# A        34.947227  3377288        0.0           0.0  2013    34.523258
# A        34.895039  2530939        0.0           0.0  2013    34.947227
# A        35.762539  4268513        0.0           0.0  2013    34.895039
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.297791  1871700        0.0           0.0  2024   127.529289
# YUM     127.184456  1157000        0.0           0.0  2024   128.297791
# YUM     128.622910  1482100        0.0           0.0  2024   127.184456
# YUM     128.691879  1421500        0.0           0.0  2024   128.622910
# YUM     127.578560  2154200        0.0           0.0  2024   128.691879
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005263                0
# A       0.012281                1
# A      -0.001493                0
# A       0.024860                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-10-25 15:35:51,829, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-10-25 15:35:51,829, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-10-25 15:35:51,834, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-10-25 15:35:51,834, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-10-25 15:35:51,850, data_manager.py, 58, INFO, Processing all tickers
# 2024-10-25 15:35:51,850, data_manager.py, 58, INFO, Processing all tickers
# 2024-10-25 15:35:51,853, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-10-25 15:35:51,853, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-10-25 15:35:51,856, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-10-25
# 2024-10-25 15:35:51,856, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:35:52,300, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-10-25 15:35:52,300, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-10-25 15:35:53,138, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-10-25 15:35:53,138, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-10-25 15:35:53,140, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-10-25
# 2024-10-25 15:35:53,140, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:35:53,695, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-10-25 15:35:53,695, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-10-25 15:35:54,370, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-10-25 15:35:54,370, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-10-25 15:35:54,374, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-10-25
# 2024-10-25 15:35:54,374, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:35:55,021, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-10-25 15:35:55,021, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-10-25 15:35:55,640, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-10-25 15:35:55,640, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-10-25 15:35:55,646, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-10-25
# 2024-10-25 15:35:55,646, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:35:55,968, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-10-25 15:35:55,968, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-10-25 15:35:56,344, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-10-25 15:35:56,344, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-10-25 15:35:56,347, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-10-25
# 2024-10-25 15:35:56,347, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:35:56,807, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-10-25 15:35:56,807, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-10-25 15:35:57,436, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-10-25 15:35:57,436, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-10-25 15:35:57,438, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-10-25
# 2024-10-25 15:35:57,438, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:35:57,903, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-10-25 15:35:57,903, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-10-25 15:35:58,603, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-10-25 15:35:58,603, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-10-25 15:35:58,607, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-10-25
# 2024-10-25 15:35:58,607, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:35:58,986, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-10-25 15:35:58,986, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-10-25 15:35:59,701, data_manager.py, 73, INFO, Processing ticker AES
# 2024-10-25 15:35:59,701, data_manager.py, 73, INFO, Processing ticker AES
# 2024-10-25 15:35:59,704, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-10-25
# 2024-10-25 15:35:59,704, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:00,271, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-10-25 15:36:00,271, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-10-25 15:36:00,917, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-10-25 15:36:00,917, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-10-25 15:36:00,919, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:00,919, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:01,409, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-10-25 15:36:01,409, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-10-25 15:36:02,120, data_manager.py, 73, INFO, Processing ticker A
# 2024-10-25 15:36:02,120, data_manager.py, 73, INFO, Processing ticker A
# 2024-10-25 15:36:02,125, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:02,125, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:02,495, data_manager.py, 83, INFO, Saving data for A by year
# 2024-10-25 15:36:02,495, data_manager.py, 83, INFO, Saving data for A by year
# 2024-10-25 15:36:03,311, data_manager.py, 73, INFO, Processing ticker APD
# 2024-10-25 15:36:03,311, data_manager.py, 73, INFO, Processing ticker APD
# 2024-10-25 15:36:03,315, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:03,315, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:03,836, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-10-25 15:36:03,836, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-10-25 15:36:04,600, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-10-25 15:36:04,600, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-10-25 15:36:04,605, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:04,605, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:04,748, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-10-25 15:36:04,748, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-10-25 15:36:04,918, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-10-25 15:36:04,918, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-10-25 15:36:04,920, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:04,920, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:05,261, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-10-25 15:36:05,261, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-10-25 15:36:05,954, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-10-25 15:36:05,954, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-10-25 15:36:05,955, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:05,955, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:06,445, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-10-25 15:36:06,445, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-10-25 15:36:07,161, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-10-25 15:36:07,161, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-10-25 15:36:07,164, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:07,164, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:07,660, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-10-25 15:36:07,660, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-10-25 15:36:08,357, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-10-25 15:36:08,357, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-10-25 15:36:08,361, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:08,361, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:08,715, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-10-25 15:36:08,715, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-10-25 15:36:09,359, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-10-25 15:36:09,359, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-10-25 15:36:09,361, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:09,361, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:09,728, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-10-25 15:36:09,728, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-10-25 15:36:10,073, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-10-25 15:36:10,073, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-10-25 15:36:10,076, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:10,076, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:10,580, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-10-25 15:36:10,580, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-10-25 15:36:11,334, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-10-25 15:36:11,334, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-10-25 15:36:11,336, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:11,336, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:11,763, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-10-25 15:36:11,763, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-10-25 15:36:12,458, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-10-25 15:36:12,458, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-10-25 15:36:12,461, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:12,461, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:12,906, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-10-25 15:36:12,906, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-10-25 15:36:13,523, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-10-25 15:36:13,523, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-10-25 15:36:13,526, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:13,526, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:13,930, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-10-25 15:36:13,930, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-10-25 15:36:14,460, data_manager.py, 73, INFO, Processing ticker MO
# 2024-10-25 15:36:14,460, data_manager.py, 73, INFO, Processing ticker MO
# 2024-10-25 15:36:14,462, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:14,462, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:15,026, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-10-25 15:36:15,026, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-10-25 15:36:15,744, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-10-25 15:36:15,744, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-10-25 15:36:15,746, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:15,746, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:16,035, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-10-25 15:36:16,035, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-10-25 15:36:16,809, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-10-25 15:36:16,809, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-10-25 15:36:16,813, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:16,813, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:17,147, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-10-25 15:36:17,147, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-10-25 15:36:17,554, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-10-25 15:36:17,554, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-10-25 15:36:17,556, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:17,556, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:17,963, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-10-25 15:36:17,963, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-10-25 15:36:18,614, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-10-25 15:36:18,614, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-10-25 15:36:18,617, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:18,617, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:18,957, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-10-25 15:36:18,957, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-10-25 15:36:19,528, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-10-25 15:36:19,528, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-10-25 15:36:19,531, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:19,531, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:20,136, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-10-25 15:36:20,136, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-10-25 15:36:20,935, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-10-25 15:36:20,935, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-10-25 15:36:20,936, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:20,936, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:21,477, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-10-25 15:36:21,477, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-10-25 15:36:22,178, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-10-25 15:36:22,178, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-10-25 15:36:22,182, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:22,182, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:22,714, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-10-25 15:36:22,714, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-10-25 15:36:23,407, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-10-25 15:36:23,407, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-10-25 15:36:23,409, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:23,409, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:23,799, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-10-25 15:36:23,799, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-10-25 15:36:24,483, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-10-25 15:36:24,483, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-10-25 15:36:24,485, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:24,485, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:24,759, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-10-25 15:36:24,759, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-10-25 15:36:25,243, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-10-25 15:36:25,243, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-10-25 15:36:25,246, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:25,246, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:25,595, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-10-25 15:36:25,595, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-10-25 15:36:26,123, data_manager.py, 73, INFO, Processing ticker AME
# 2024-10-25 15:36:26,123, data_manager.py, 73, INFO, Processing ticker AME
# 2024-10-25 15:36:26,126, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:26,126, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:26,681, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-10-25 15:36:26,681, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-10-25 15:36:27,393, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-10-25 15:36:27,393, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-10-25 15:36:27,396, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:27,396, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:27,703, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-10-25 15:36:27,703, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-10-25 15:36:28,362, data_manager.py, 73, INFO, Processing ticker APH
# 2024-10-25 15:36:28,362, data_manager.py, 73, INFO, Processing ticker APH
# 2024-10-25 15:36:28,365, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:28,365, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:28,819, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-10-25 15:36:28,819, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-10-25 15:36:29,496, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-10-25 15:36:29,496, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-10-25 15:36:29,497, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:29,497, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:29,919, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-10-25 15:36:29,919, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-10-25 15:36:30,596, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-10-25 15:36:30,596, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-10-25 15:36:30,597, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:30,597, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ANSS']: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)"))
# 2024-10-25 15:36:40,711, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-10-25 15:36:40,711, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-10-25 15:36:40,716, data_manager.py, 101, WARNING, No data found for ANSS
# 2024-10-25 15:36:40,716, data_manager.py, 101, WARNING, No data found for ANSS
# 2024-10-25 15:36:40,724, data_manager.py, 73, INFO, Processing ticker AON
# 2024-10-25 15:36:40,724, data_manager.py, 73, INFO, Processing ticker AON
# 2024-10-25 15:36:40,734, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:40,734, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:41,449, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-10-25 15:36:41,449, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-10-25 15:36:42,370, data_manager.py, 73, INFO, Processing ticker APA
# 2024-10-25 15:36:42,370, data_manager.py, 73, INFO, Processing ticker APA
# 2024-10-25 15:36:42,375, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:42,375, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:42,896, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-10-25 15:36:42,896, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-10-25 15:36:43,539, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-10-25 15:36:43,539, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-10-25 15:36:43,542, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:43,542, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:43,903, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-10-25 15:36:43,903, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-10-25 15:36:44,661, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-10-25 15:36:44,661, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-10-25 15:36:44,665, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:44,665, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:45,082, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-10-25 15:36:45,082, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-10-25 15:36:45,876, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-10-25 15:36:45,876, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-10-25 15:36:45,878, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:45,878, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:46,261, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-10-25 15:36:46,261, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-10-25 15:36:46,651, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-10-25 15:36:46,651, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-10-25 15:36:46,655, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:46,655, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:46,978, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-10-25 15:36:46,978, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-10-25 15:36:47,608, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-10-25 15:36:47,608, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-10-25 15:36:47,611, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:47,611, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:48,103, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-10-25 15:36:48,103, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-10-25 15:36:48,797, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-10-25 15:36:48,797, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-10-25 15:36:48,801, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:48,801, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:49,083, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-10-25 15:36:49,083, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-10-25 15:36:49,382, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-10-25 15:36:49,382, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-10-25 15:36:49,385, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:49,385, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:49,924, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-10-25 15:36:49,924, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-10-25 15:36:50,693, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-10-25 15:36:50,693, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-10-25 15:36:50,697, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:50,697, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:51,137, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-10-25 15:36:51,137, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-10-25 15:36:51,716, data_manager.py, 73, INFO, Processing ticker T
# 2024-10-25 15:36:51,716, data_manager.py, 73, INFO, Processing ticker T
# 2024-10-25 15:36:51,718, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:51,718, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:52,204, data_manager.py, 83, INFO, Saving data for T by year
# 2024-10-25 15:36:52,204, data_manager.py, 83, INFO, Saving data for T by year
# 2024-10-25 15:36:52,866, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-10-25 15:36:52,866, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-10-25 15:36:52,868, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:52,868, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:53,336, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-10-25 15:36:53,336, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-10-25 15:36:54,049, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-10-25 15:36:54,049, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-10-25 15:36:54,051, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:54,051, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:54,628, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-10-25 15:36:54,628, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-10-25 15:36:55,411, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-10-25 15:36:55,411, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-10-25 15:36:55,412, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:55,412, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:55,944, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-10-25 15:36:55,944, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-10-25 15:36:56,679, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-10-25 15:36:56,679, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-10-25 15:36:56,681, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:56,681, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:57,029, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-10-25 15:36:57,029, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-10-25 15:36:57,625, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-10-25 15:36:57,625, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-10-25 15:36:57,626, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:57,626, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:58,027, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-10-25 15:36:58,027, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-10-25 15:36:58,762, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-10-25 15:36:58,762, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-10-25 15:36:58,763, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:58,763, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:59,207, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-10-25 15:36:59,207, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-10-25 15:36:59,647, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-10-25 15:36:59,647, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-10-25 15:36:59,648, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-10-25
# 2024-10-25 15:36:59,648, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:36:59,936, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-10-25 15:36:59,936, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-10-25 15:37:00,326, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-10-25 15:37:00,326, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-10-25 15:37:00,328, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:00,328, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:00,740, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-10-25 15:37:00,740, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-10-25 15:37:01,133, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-10-25 15:37:01,133, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-10-25 15:37:01,135, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:01,135, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:01,606, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-10-25 15:37:01,606, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-10-25 15:37:02,019, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-10-25 15:37:02,019, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-10-25 15:37:02,021, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:02,021, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:02,558, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-10-25 15:37:02,558, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-10-25 15:37:03,451, data_manager.py, 73, INFO, Processing ticker BK
# 2024-10-25 15:37:03,451, data_manager.py, 73, INFO, Processing ticker BK
# 2024-10-25 15:37:03,454, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:03,454, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:04,054, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-10-25 15:37:04,054, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-10-25 15:37:04,859, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-10-25 15:37:04,859, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-10-25 15:37:04,861, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:04,861, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:05,430, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-10-25 15:37:05,430, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-10-25 15:37:06,380, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-10-25 15:37:06,380, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-10-25 15:37:06,383, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:06,383, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:06,914, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-10-25 15:37:06,914, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-10-25 15:37:07,589, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-10-25 15:37:07,589, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-10-25 15:37:07,593, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:07,593, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:08,138, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-10-25 15:37:08,138, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-10-25 15:37:08,693, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-10-25 15:37:08,693, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-10-25 15:37:08,696, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:08,696, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-10-25 15:37:09,992, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-10-25 15:37:09,992, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-10-25 15:37:09,995, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-10-25 15:37:09,995, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-10-25 15:37:09,997, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-10-25 15:37:09,997, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-10-25 15:37:10,000, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:10,000, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:10,398, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-10-25 15:37:10,398, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-10-25 15:37:11,280, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-10-25 15:37:11,280, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-10-25 15:37:11,284, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:11,284, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:11,686, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-10-25 15:37:11,686, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-10-25 15:37:12,603, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-10-25 15:37:12,603, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-10-25 15:37:12,605, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:12,605, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:13,058, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-10-25 15:37:13,058, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-10-25 15:37:13,801, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-10-25 15:37:13,801, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-10-25 15:37:13,803, data_manager.py, 109, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:13,803, data_manager.py, 109, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:14,186, data_manager.py, 83, INFO, Saving data for BIIB by year
# 2024-10-25 15:37:14,186, data_manager.py, 83, INFO, Saving data for BIIB by year
# 2024-10-25 15:37:15,048, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-10-25 15:37:15,048, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-10-25 15:37:15,051, data_manager.py, 109, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:15,051, data_manager.py, 109, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:15,471, data_manager.py, 83, INFO, Saving data for BLK by year
# 2024-10-25 15:37:15,471, data_manager.py, 83, INFO, Saving data for BLK by year
# 2024-10-25 15:37:16,407, data_manager.py, 73, INFO, Processing ticker BX
# 2024-10-25 15:37:16,407, data_manager.py, 73, INFO, Processing ticker BX
# 2024-10-25 15:37:16,411, data_manager.py, 109, INFO, Getting stock price data for BX from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:16,411, data_manager.py, 109, INFO, Getting stock price data for BX from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:16,761, data_manager.py, 83, INFO, Saving data for BX by year
# 2024-10-25 15:37:16,761, data_manager.py, 83, INFO, Saving data for BX by year
# 2024-10-25 15:37:17,626, data_manager.py, 73, INFO, Processing ticker BA
# 2024-10-25 15:37:17,626, data_manager.py, 73, INFO, Processing ticker BA
# 2024-10-25 15:37:17,629, data_manager.py, 109, INFO, Getting stock price data for BA from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:17,629, data_manager.py, 109, INFO, Getting stock price data for BA from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:18,183, data_manager.py, 83, INFO, Saving data for BA by year
# 2024-10-25 15:37:18,183, data_manager.py, 83, INFO, Saving data for BA by year
# 2024-10-25 15:37:19,361, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-10-25 15:37:19,361, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-10-25 15:37:19,366, data_manager.py, 109, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:19,366, data_manager.py, 109, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:19,748, data_manager.py, 83, INFO, Saving data for BKNG by year
# 2024-10-25 15:37:19,748, data_manager.py, 83, INFO, Saving data for BKNG by year
# 2024-10-25 15:37:20,999, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-10-25 15:37:20,999, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-10-25 15:37:21,004, data_manager.py, 109, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:21,004, data_manager.py, 109, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:21,611, data_manager.py, 83, INFO, Saving data for BWA by year
# 2024-10-25 15:37:21,611, data_manager.py, 83, INFO, Saving data for BWA by year
# 2024-10-25 15:37:22,670, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-10-25 15:37:22,670, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-10-25 15:37:22,673, data_manager.py, 109, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:22,673, data_manager.py, 109, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:23,144, data_manager.py, 83, INFO, Saving data for BXP by year
# 2024-10-25 15:37:23,144, data_manager.py, 83, INFO, Saving data for BXP by year
# 2024-10-25 15:37:24,036, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-10-25 15:37:24,036, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-10-25 15:37:24,039, data_manager.py, 109, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:24,039, data_manager.py, 109, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:24,358, data_manager.py, 83, INFO, Saving data for BSX by year
# 2024-10-25 15:37:24,358, data_manager.py, 83, INFO, Saving data for BSX by year
# 2024-10-25 15:37:25,240, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-10-25 15:37:25,240, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-10-25 15:37:25,242, data_manager.py, 109, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:25,242, data_manager.py, 109, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:25,775, data_manager.py, 83, INFO, Saving data for BMY by year
# 2024-10-25 15:37:25,775, data_manager.py, 83, INFO, Saving data for BMY by year
# 2024-10-25 15:37:26,468, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-10-25 15:37:26,468, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-10-25 15:37:26,470, data_manager.py, 109, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:26,470, data_manager.py, 109, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:37:26,839, data_manager.py, 83, INFO, Saving data for AVGO by year
# 2024-10-25 15:37:26,839, data_manager.py, 83, INFO, Saving data for AVGO by year
# 2024-10-25 15:37:27,234, data_manager.py, 73, INFO, Processing ticker BR
# 2024-10-25 15:37:27,234, data_manager.py, 73, INFO, Processing ticker BR
# 2024-10-25 15:37:27,237, data_manager.py, 109, INFO, Getting stock price data for BR from 2000-01-01 to 2024-10-25
# 2024-10-25 15:37:27,237, data_manager.py, 109, INFO, Getting stock price data for BR from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# ...
# 2024-10-25 15:45:29,439, data_manager.py, 109, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:29,439, data_manager.py, 109, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:29,797, data_manager.py, 83, INFO, Saving data for WAB by year
# 2024-10-25 15:45:29,797, data_manager.py, 83, INFO, Saving data for WAB by year
# 2024-10-25 15:45:30,254, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-10-25 15:45:30,254, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-10-25 15:45:30,256, data_manager.py, 109, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:30,256, data_manager.py, 109, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:30,679, data_manager.py, 83, INFO, Saving data for WBA by year
# 2024-10-25 15:45:30,679, data_manager.py, 83, INFO, Saving data for WBA by year
# 2024-10-25 15:45:31,175, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-10-25 15:45:31,175, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-10-25 15:45:31,177, data_manager.py, 109, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:31,177, data_manager.py, 109, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:31,726, data_manager.py, 83, INFO, Saving data for WMT by year
# 2024-10-25 15:45:31,726, data_manager.py, 83, INFO, Saving data for WMT by year
# 2024-10-25 15:45:32,194, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-10-25 15:45:32,194, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-10-25 15:45:32,196, data_manager.py, 109, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:32,196, data_manager.py, 109, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:32,821, data_manager.py, 83, INFO, Saving data for DIS by year
# 2024-10-25 15:45:32,821, data_manager.py, 83, INFO, Saving data for DIS by year
# 2024-10-25 15:45:33,609, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-10-25 15:45:33,609, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-10-25 15:45:33,612, data_manager.py, 109, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:33,612, data_manager.py, 109, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:34,125, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-10-25 15:45:34,125, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-10-25 15:45:34,870, data_manager.py, 73, INFO, Processing ticker WM
# 2024-10-25 15:45:34,870, data_manager.py, 73, INFO, Processing ticker WM
# 2024-10-25 15:45:34,873, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:34,873, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:35,389, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-10-25 15:45:35,389, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-10-25 15:45:36,295, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-10-25 15:45:36,295, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-10-25 15:45:36,297, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:36,297, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:36,742, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-10-25 15:45:36,742, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-10-25 15:45:37,839, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-10-25 15:45:37,839, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-10-25 15:45:37,844, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:37,844, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:38,415, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-10-25 15:45:38,415, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-10-25 15:45:39,316, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-10-25 15:45:39,316, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-10-25 15:45:39,319, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:39,319, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:39,954, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-10-25 15:45:39,954, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-10-25 15:45:40,852, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-10-25 15:45:40,852, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-10-25 15:45:40,855, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:40,855, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:41,344, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-10-25 15:45:41,344, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-10-25 15:45:42,158, data_manager.py, 73, INFO, Processing ticker WST
# 2024-10-25 15:45:42,158, data_manager.py, 73, INFO, Processing ticker WST
# 2024-10-25 15:45:42,162, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:42,162, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:42,710, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-10-25 15:45:42,710, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-10-25 15:45:43,689, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-10-25 15:45:43,689, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-10-25 15:45:43,694, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:43,694, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:44,044, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-10-25 15:45:44,044, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-10-25 15:45:44,909, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-10-25 15:45:44,909, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-10-25 15:45:44,912, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:44,912, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WRK']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-10-25 15:45:46,370, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-10-25 15:45:46,370, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-10-25 15:45:46,374, data_manager.py, 101, WARNING, No data found for WRK
# 2024-10-25 15:45:46,374, data_manager.py, 101, WARNING, No data found for WRK
# 2024-10-25 15:45:46,377, data_manager.py, 73, INFO, Processing ticker WY
# 2024-10-25 15:45:46,377, data_manager.py, 73, INFO, Processing ticker WY
# 2024-10-25 15:45:46,380, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:46,380, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:46,921, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-10-25 15:45:46,921, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-10-25 15:45:47,574, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-10-25 15:45:47,574, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-10-25 15:45:47,576, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:47,576, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:48,135, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-10-25 15:45:48,135, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-10-25 15:45:49,128, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-10-25 15:45:49,128, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-10-25 15:45:49,131, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:49,131, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:49,891, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-10-25 15:45:49,891, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-10-25 15:45:50,795, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-10-25 15:45:50,795, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-10-25 15:45:50,798, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:50,798, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:51,211, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-10-25 15:45:51,211, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-10-25 15:45:52,223, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-10-25 15:45:52,223, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-10-25 15:45:52,225, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:52,225, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:52,572, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-10-25 15:45:52,572, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-10-25 15:45:53,555, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-10-25 15:45:53,555, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-10-25 15:45:53,557, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:53,557, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:54,016, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-10-25 15:45:54,016, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-10-25 15:45:54,950, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-10-25 15:45:54,950, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-10-25 15:45:54,953, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:54,953, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:55,565, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-10-25 15:45:55,565, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-10-25 15:45:56,192, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-10-25 15:45:56,192, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-10-25 15:45:56,195, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:56,195, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:56,540, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-10-25 15:45:56,540, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-10-25 15:45:57,078, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-10-25 15:45:57,078, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-10-25 15:45:57,082, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:57,082, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:57,519, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-10-25 15:45:57,519, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-10-25 15:45:58,637, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-10-25 15:45:58,637, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-10-25 15:45:58,645, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-10-25
# 2024-10-25 15:45:58,645, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:45:59,101, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-10-25 15:45:59,101, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-10-25 15:46:00,201, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-10-25 15:46:00,201, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-10-25 15:46:00,204, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-10-25
# 2024-10-25 15:46:00,204, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:46:00,648, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-10-25 15:46:00,648, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-10-25 15:46:01,745, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-10-25 15:46:01,745, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-10-25 15:46:01,752, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-10-25
# 2024-10-25 15:46:01,752, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:46:02,251, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-10-25 15:46:02,251, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-10-25 15:46:03,186, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-10-25 15:46:03,186, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-10-25 15:46:03,191, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-10-25
# 2024-10-25 15:46:03,191, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 15:46:03,538, data_manager.py, 83, INFO, Saving data for ZTS by year
# 2024-10-25 15:46:03,538, data_manager.py, 83, INFO, Saving data for ZTS by year

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-10-25 15:46:03,981, data_manager.py, 121, INFO, Creating features data.
# 2024-10-25 15:46:03,981, data_manager.py, 121, INFO, Creating features data.
# 2024-10-25 15:46:03,984, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# 2024-10-25 15:46:03,984, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# 2024-10-25 15:46:07,320, data_manager.py, 140, INFO, Creating features
# 2024-10-25 15:46:07,320, data_manager.py, 140, INFO, Creating features
# c:\Users\xiaoy\production\01_materials\labs\../../05_src\data_manager.py:142: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-10-25 15:46:07,334, data_manager.py, 158, INFO, Creating target
# 2024-10-25 15:46:07,334, data_manager.py, 158, INFO, Creating target
# c:\Users\xiaoy\production\01_materials\labs\../../05_src\data_manager.py:159: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-10-25 15:46:07,346, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-10-25 15:46:07,346, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
